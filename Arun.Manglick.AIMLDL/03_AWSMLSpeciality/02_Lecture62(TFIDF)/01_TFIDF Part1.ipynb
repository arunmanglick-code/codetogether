# %% [markdown]
# # TF-IDF - A popular technique in NLP for text processing

# %%
# Lab experiment on TF-IDF (Term Frequency-Inverse Document Frequency), a popular technique in NLP for text processing
# Figures out what terms are most relevant for a document
# Term Frequency: Measures how often a word occurs in a document
# Inverse Document Frequency - Measures how important a word is across all documents

# TF-IDF = Term Frequency / Document Frequency (I.e.# TF-IDF = (Number of times term t appears in document d) / (Total number of documents containing term t)
# OR
# TF-IDF = Term Frequency * Inverse Document Frequency

# Using TF-IDF
    # Compute TF-IDF for every word in a corpus
    # For a given search word, sort the documents by their TF-IDF score for that word
    # Display the results

# Import required libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# Sample corpus of documents
documents = [
    "The cat sat on the mat.",
    "The dog sat on the log.",
    "Cats and dogs are great pets.",
    "Dogs are loyal and friendly.",
    "Cats are independent and curious."
]

# documents = [
#     "The cat sat on the mat.",
#     "The cat sat on the mat.",
#     "The cat sat on the mat.",
#     "The cat sat on the mat.",
#     "The cat sat on the mat.",
#     "The cat sat on the mat."
# ]

# documents = [
#    "Machine learning is amazing",
#         "Deep learning drives AI advancements",
#         "AI and machine learning revolutionize industries",
#         "Data science is the backbone of AI",
#         "AI models require vast amounts of training data"
# ]

# Create a TfidfVectorizer instance (To converts text into numerical feature representation)
vectorizer = TfidfVectorizer()

# Fit and transform the corpus of documents to compute the TF-IDF matrix (I.e. Apply TF-IDF transformation)
# Assigns weights based on word frequency & uniqueness in documents
tfidf_matrix = vectorizer.fit_transform(documents)

# Convert the TF-IDF matrix to a DataFrame for better readability   
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

# Display the TF-IDF DataFrame  
print("TF-IDF Matrix:")
print(tfidf_df)

#Explanation:
# tfidfVectorizer converts text into numerical feature representation. 
# It assigns weights based on word frequency & uniqueness in documents. 
# The final matrix provides TF-IDF scores for each word, helping in feature extraction for ML models.
# Out:
# TF-IDF Matrix:
#         and       are       cat      cats   curious       dog      dogs  \
# 0  0.000000  0.000000  0.411502  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.411502  0.000000
# 2  0.326830  0.326830  0.000000  0.393728  0.000000  0.000000  0.393728
# 3  0.355549  0.355549  0.000000  0.000000  0.000000  0.000000  0.428326
# 4  0.355549  0.355549  0.000000  0.428326  0.530899  0.000000  0.000000
#
#    friendly     great  independent       log     loyal       mat        on  \
# 0  0.000000  0.000000     0.000000  0.000000  0.000000  0.411502  0.331997
# 1  0.000000  0.000000     0.000000  0.411502  0.000000  0.000000  0.331997
# 2  0.000000  0.488016     0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.530899  0.000000     0.000000  0.000000  0.530899  0.000000  0.000000
# 4  0.000000  0.000000     0.530899  0.000000  0.000000  0.000000  0.000000
#
#        pets       sat       the
# ...
