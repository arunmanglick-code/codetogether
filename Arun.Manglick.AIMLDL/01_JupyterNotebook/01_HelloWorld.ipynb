# %% [markdown]
# # Section 1 Jupyter Notebook

# %%
print ('Hello Code From Section 1 in Python')
# Out:
# Hello Code From Section 1 in Python

# %% [markdown]
# # Section 2 Jupyter Notebook

# %%
print ('Hello Code From Section 2 in Python')
# Out:
# Hello Code From Section 2 in Python
